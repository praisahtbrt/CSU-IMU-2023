# %% [markdown]
# <a href="https://colab.research.google.com/github/praisahtbrt/CSU-IMU-2023/blob/main/Assignment%201_21949.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Data Health Insurance Claims

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Ngeread data
df = pd.read_csv('health_insurance_claims.csv', sep=",", na_values=['NaN'])
print(f'Loaded shape: {df.shape}')
df.head(10)
# Out:
# Loaded shape: (10000, 7)
#    claim_id   age  gender policy_type diagnosis_code  claim_amount  \
# 0         1  69.0    Male    Standard           D001       9536.85
# 1         2  32.0    Male       Basic           D004      13215.40
# 2         3  89.0  Female     Premium           D004       2053.08
# 3         4  78.0    Male       Basic           D001       6538.17
# 4         5  38.0  Female       Basic           D003       4424.58
# 5         6  41.0    Male    Standard           D005       6214.82
# 6         7  20.0    Male    Standard            NaN       4845.43
# 7         8  39.0    Male    Standard           D003       5391.60
# 8         9  70.0  Female    Standard           D005      10029.57
# 9        10  19.0    Male       Basic           D004       2950.42
#
#   payment_status
# 0        Pending
# 1        Pending
# 2        Pending
# 3           Paid
# 4           Paid
# 5           Paid
# 6           Paid
# 7           Paid
# 8           Paid
# 9           Paid

# %% [markdown]
# ## Initial Inspection
#
# **Show dataset shape and first 10 rows**

# %%
print('Shape:', df.shape) #nampilin ukuran df(baris (banyak data), column (fitur data))
display(df.head(10))
# Out:
# Shape: (10000, 7)
#    claim_id   age  gender policy_type diagnosis_code  claim_amount  \
# 0         1  69.0    Male    Standard           D001       9536.85
# 1         2  32.0    Male       Basic           D004      13215.40
# 2         3  89.0  Female     Premium           D004       2053.08
# 3         4  78.0    Male       Basic           D001       6538.17
# 4         5  38.0  Female       Basic           D003       4424.58
# 5         6  41.0    Male    Standard           D005       6214.82
# 6         7  20.0    Male    Standard            NaN       4845.43
# 7         8  39.0    Male    Standard           D003       5391.60
# 8         9  70.0  Female    Standard           D005      10029.57
# 9        10  19.0    Male       Basic           D004       2950.42
#
#   payment_status
# 0        Pending
# 1        Pending
# 2        Pending
# 3           Paid
# 4           Paid
# 5           Paid
# 6           Paid
# 7           Paid
# 8           Paid
# 9           Paid

# %%
print('\nInfo:')
df.info() #ringkasan struktur dataset
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   claim_id        10000 non-null  int64
#  1   age             9800 non-null   float64
#  2   gender          10000 non-null  object
#  3   policy_type     10000 non-null  object
#  4   diagnosis_code  9800 non-null   object
#  5   claim_amount    9800 non-null   float64
#  6   payment_status  10000 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 547.0+ KB

# %% [markdown]
# **Summary statistics for numeric columns**

# %%
print('\nDescribe (numeric):')
df.describe() #statistik ringkas
# Out:
# Describe (numeric):
#           claim_id          age  claim_amount
# count  10000.00000  9800.000000   9800.000000
# mean    5000.50000    53.582959   4008.560987
# std     2886.89568    20.749805   2843.926721
# min        1.00000    18.000000     50.220000
# 25%     2500.75000    36.000000   1890.927500
# 50%     5000.50000    53.000000   3352.395000
# 75%     7500.25000    72.000000   5407.177500
# max    10000.00000    89.000000  21581.180000

# %% [markdown]
# **Identify numeric vs categorical variables**
#
# Tipe data df:
#
#
# *   int64 → bilangan bulat
# *   float64 → bilangan pecahan
# *   object → teks/string atau campuran
# *   datetime64 → waktu/tanggal

# %%
print('\nColumn dtypes:')
df.dtypes #nampilin tipe data per kolom
# Out:
# Column dtypes:
# claim_id            int64
# age               float64
# gender             object
# policy_type        object
# diagnosis_code     object
# claim_amount      float64
# payment_status     object
# dtype: object

# %% [markdown]
# ## Missing Values
#
# **Count missing values per column**

# %%
missing_before = df.isna().sum()
print('Missing before:\n', missing_before)
# Out:
# Missing before:
#  claim_id            0
# age               200
# gender              0
# policy_type         0
# diagnosis_code    200
# claim_amount      200
# payment_status      0
# dtype: int64

# %%
# Impute age with median
if 'age' in df.columns:
    df['age'] = df['age'].fillna(df['age'].median())

# Impute claim_amount with your choice (mean or median) – default median here
if 'claim_amount' in df.columns:
    df['claim_amount'] = df['claim_amount'].fillna(df['claim_amount'].median())

# Impute diagnosis_code with mode (most frequent)
if 'diagnosis_code' in df.columns:
    mode_val = df['diagnosis_code'].mode(dropna=True)
    if len(mode_val) > 0:
        df['diagnosis_code'] = df['diagnosis_code'].fillna(mode_val.iloc[0])

missing_after = df.isna().sum()
print('\nMissing after:\n', missing_after)
# Out:
# Missing after:
#  claim_id          0
# age               0
# gender            0
# policy_type       0
# diagnosis_code    0
# claim_amount      0
# payment_status    0
# dtype: int64

# %% [markdown]
# INTERPRETASI KYA NISA
